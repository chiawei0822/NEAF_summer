# %%
# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# Out:
# ^C
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 讀取與顯示數位影像

# %%
img_ori=cv2.imread(r"input\lena.bmp",-1)#讀取影像檔案，第二個參數為影像的讀取方式
cv2.imshow("ex_test",img_ori)#建立視窗
cv2.waitKey(0)#第6行WaitKey等待使用者的鍵盤輸入，單位為毫秒(ms)，例如1,000 代表等待1秒再關閉視窗，0則表示持續等待使用者輸入任意鑑後再關閉視窗。
cv2.destroyAllWindows()#關閉所有視窗

# %% [markdown]
# ## 1. Histogram Equalization
# Histogram is the method to enhance image contrast.
# Please show the image grayscale histogram and do the equlization, and show the image result and histogram equalization result.

# %%
img_ori = cv2.imread("input\lena.bmp", cv2.IMREAD_GRAYSCALE) # Read image as gray.

plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.imshow(img_ori,cmap='gray')
plt.title("origin")
plt.axis("off")

hist1 = cv2.calcHist([img_ori], [0], None, [256], [0, 256])
plt.subplot(2,2,2)
plt.bar(range(256), hist1.flatten(), width=1)

equalize_img = cv2.equalizeHist(img_ori)
plt.subplot(2,2,3)
plt.imshow(equalize_img,cmap='gray')
plt.title("equalize")
plt.axis("off")

hist2 = cv2.calcHist([equalize_img], [0], None, [256], [0, 256])
plt.subplot(2,2,4)
plt.bar(range(256), hist2.flatten(), width=1)
# plt.plot(hist2)

# save result
cv2.imwrite('output/img_ori.bmp', img_ori)
cv2.imwrite('output/img_equa.bmp', equalize_img)
# Out:
# True

# %% [markdown]
# ## 2.Mean blur, Gaussian blur, Median blur
# Blur is a method to deal with the noise on the image. Please input the image and use different kernel size to show blur result.

# %%
img_noise = cv2.imread("input\lena_noise.png", cv2.IMREAD_GRAYSCALE)
plt.subplot(1,4,1)
plt.imshow(img_noise,cmap='gray')
plt.title("origin")
plt.axis("off")

# Blur the image by three methods.
image_meanBlur = cv2.blur(img_noise, (5,5))
image_GaussianBlur = cv2.GaussianBlur(img_noise, (5,5),0)
image_medianBlur = cv2.medianBlur(img_noise, 5)

#save result
cv2.imwrite('output/img_mean_blur.png', image_meanBlur)
cv2.imwrite('output/img_gaussian_blur.png', image_GaussianBlur)
cv2.imwrite('output/img_median_blur.png', image_medianBlur)

plt.subplot(1,4,2)
plt.imshow(image_meanBlur,cmap='gray')
plt.title("meanBlur")
plt.axis("off")

plt.subplot(1,4,3)
plt.imshow(image_GaussianBlur,cmap='gray')
plt.title("GaussianBlur")
plt.axis("off")

plt.subplot(1,4,4)
plt.imshow(image_medianBlur,cmap='gray')
plt.title("medianBlur")
plt.axis("off")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# <>:1: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\vivian\AppData\Local\Temp\ipykernel_17620\2922659964.py:1: SyntaxWarning: invalid escape sequence '\l'
#   img_noise = cv2.imread("input\lena_noise.png", cv2.IMREAD_GRAYSCALE)
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %% [markdown]
# ## 3. Binary
# Binary is a method to transfer greyscale to 0 (black) and 255 (white) only.
# Please do the image binary to seperate pad and background.

# %%
binary1 = cv2.imread('input/binary_task1.bmp', cv2.IMREAD_GRAYSCALE)
plt.subplot(2,2,1)
plt.imshow(binary1,cmap='gray')
plt.title("origin")
plt.axis("off")

hist1 = cv2.calcHist([binary1], [0], None, [256], [0, 256])
plt.subplot(2,2,2)
plt.bar(range(256), hist1.flatten(), width=1)

# Do the image binary to seperate pad and background
_, image_binary1 = cv2.threshold(binary1, 100, 255, cv2.THRESH_BINARY) ## (threshold, image)
print("_ = ", _)
plt.subplot(2,2,3)
plt.imshow(image_binary1,cmap="gray")
plt.title("threshold")
plt.axis("off")

hist2 = cv2.calcHist([image_binary1], [0], None, [256], [0, 256])
plt.subplot(2,2,4)
plt.bar(range(256), hist2.flatten(), width=2)
# plt.plot(hist2)

# save result
cv2.imwrite('output/binary_task1.bmp', image_binary1)
# Out:
# _ =  100.0
# True

# %%
binary2 = cv2.imread('input/binary_task2.bmp', cv2.IMREAD_GRAYSCALE)
plt.subplot(2,2,1)
plt.imshow(binary2,cmap='gray')
plt.title("origin")
plt.axis("off")

hist1 = cv2.calcHist([binary2], [0], None, [256], [0, 256])
plt.subplot(2,2,2)
plt.bar(range(256), hist1.flatten(), width=2)

# Do the image binary to seperate pad and background
_, image_binary2 = cv2.threshold(binary2, 120, 255, cv2.THRESH_BINARY) ## (threshold, image)
print("_ = ", _)
plt.subplot(2,2,3)
plt.imshow(image_binary2,cmap="gray")
plt.title("threshold")
plt.axis("off")

hist2 = cv2.calcHist([image_binary2], [0], None, [256], [0, 256])
plt.subplot(2,2,4)
plt.bar(range(256), hist2.flatten(), width=2)

# save result
cv2.imwrite('output/binary_task2.bmp', image_binary2)
# Out:
# _ =  120.0
# True

# %%
binary3 = cv2.imread('input/binary_task3.bmp', cv2.IMREAD_GRAYSCALE)
plt.subplot(2,2,1)
plt.imshow(binary3,cmap='gray')
plt.title("origin")
plt.axis("off")

hist1 = cv2.calcHist([binary3], [0], None, [256], [0, 256])
plt.subplot(2,2,2)
plt.bar(range(256), hist1.flatten(), width=2)

# Do the image binary to seperate pad and background
_, image_binary3 = cv2.threshold(binary3, 140, 255, cv2.THRESH_BINARY) ## (threshold, image)
print("_ = ", _)
plt.subplot(2,2,3)
plt.imshow(image_binary3,cmap="gray")
plt.title("threshold")
plt.axis("off")

hist2 = cv2.calcHist([image_binary3], [0], None, [256], [0, 256])
plt.subplot(2,2,4)
plt.bar(range(256), hist2.flatten(), width=2)

# save result
cv2.imwrite('output/binary_task3.bmp', image_binary3)
# Out:
# _ =  140.0
# True

# %% [markdown]
# ## 4. HSV filter
# This method could extract the the interested part by color.
# Please crop the yellow or blue boxes and its surrounding in the image.

# %%
import numpy as np

# Yellow box.
yellow = cv2.imread('input/yellow.jpg')

# Step 1. Transfer color to HSV
image_hsv = cv2.cvtColor(yellow, cv2.COLOR_BGR2HSV)

# Step 2. Setting the color range and filter the image.
# lowerb = np.array([26,43,46])
# upperb = np.array([99,255,255])
lowerb = np.array([30,100,100])
upperb = np.array([34,255,255])
mask = cv2.inRange(image_hsv, lowerb, upperb)
# print(mask)

image_masked = cv2.bitwise_and(yellow, yellow, mask=mask)
image_yellow = cv2.cvtColor(yellow, cv2.COLOR_BGR2RGB)

image_list = [yellow, image_hsv, mask, image_masked, image_yellow]
title_list = ['yellow', 'image_hsv', 'mask', 'image_masked', 'image_yellow']
plt.figure(figsize=(40,8))
for i in range(len(title_list)):
    plt.subplot(1,5,i+1)
    plt.imshow(image_list[i],cmap="gray")
    plt.title(title_list[i],size=30)
    plt.axis("off")



# Step 3. Binary the image, find the left-top and right-bottom coordinate (x, y, w, h) or (x1, x2, y1, y2).
x_arr = []; y_arr=[]
for i in range(len(mask)):
    for j in range(len(mask[0])):
        if mask[i][j] != 0:
            # print(i,j,mask[i][j])
            x_arr.append(i)
            y_arr.append(j)

x_max = max(x_arr)
x_min = min(x_arr)
y_max = max(y_arr)
y_min = min(y_arr)
print('x_max = ', x_max, '\nx_min = ', x_min, '\ny_max = ', y_max,'\ny_min = ',  y_min)


# Step 4. Crop the image by the coordinate.
crop_edge = 20  # surrounding 20 pixels 
cropHSV_yellow = image_yellow[x_min-crop_edge: x_max+crop_edge, y_min-crop_edge: y_max+crop_edge]   # take (x, y, w, h) as example.

plt.figure()
plt.imshow(cropHSV_yellow)
plt.title("cropHSV_yellow")
plt.axis("off")

# save result
cv2.imwrite('output/cropHSV_yellow.jpg', cropHSV_yellow)
# Out:
# x_max =  2537
# x_min =  2531
# y_max =  3189
# y_min =  3171
# True

# %%
import numpy as np
# Blue box.
blue = cv2.imread('input/blue.jpg')

# Step 1. Transfer color to HSV
image_hsv = cv2.cvtColor(blue, cv2.COLOR_BGR2HSV)

# Step 2. Setting the color range and filter the image.
lowerb = np.array([110, 100, 100])
upperb = np.array([125, 255, 255])
mask = cv2.inRange(image_hsv, lowerb, upperb)
image_masked = cv2.bitwise_and(blue, blue, mask=mask)
image_blue = cv2.cvtColor(blue, cv2.COLOR_BGR2RGB)

# Step 3. Binary the image, find the left-top and right-bottom coordinate (x, y, w, h) or (x1, x2, y1, y2).
x_arr = []; y_arr=[]
for i in range(len(mask)):
    for j in range(len(mask[0])):
        if mask[i][j] != 0:
            # print(i,j,mask[i][j])
            x_arr.append(i)
            y_arr.append(j)

x_max = max(x_arr)
x_min = min(x_arr)
y_max = max(y_arr)
y_min = min(y_arr)
print('x_max = ', x_max, '\nx_min = ', x_min, '\ny_max = ', y_max,'\ny_min = ',  y_min)


# Step 4. Crop the image by the coordinate.
crop_edge = 20  # surrounding 20 pixels 
cropHSV_blue = image_blue[x_min-crop_edge: x_max+crop_edge, y_min-crop_edge: y_max+crop_edge]   # take (x, y, w, h) as example.

plt.figure()
plt.imshow(cropHSV_blue)
plt.title("cropHSV_blue")
plt.axis("off")

# save result
cv2.imwrite('output/cropHSV_blue.jpg', cropHSV_blue)
# Out:
# x_max =  2582
# x_min =  2529
# y_max =  1369
# y_min =  1317
# True

# %% [markdown]
# ## 5. Morphological: erosion, dilation, open, close
#
# Those methods help to denoise, enhance the features.
# Please use these methods to fill up the lines of the image created in the previous section.

# %%
hsv_yellow = cv2.imread('output/cropHSV_yellow.jpg')
plt.figure(figsize=(20,6.5))
plt.subplot(2,4,1)
plt.imshow(hsv_yellow,cmap='gray')
plt.title("origin")
plt.axis("off")

hist1 = cv2.calcHist([hsv_yellow], [0], None, [256], [0, 256])
plt.subplot(2,4,2)
plt.bar(range(256), hist1.flatten(), width=2)

gray = cv2.cvtColor(hsv_yellow, cv2.COLOR_BGR2GRAY)
_, image_binary = cv2.threshold(gray, 110, 255, cv2.THRESH_BINARY) ## (threshold, image)

print("_ = ", _)
plt.subplot(2,4,3)
plt.imshow(image_binary,cmap="gray")
plt.title("threshold")
plt.axis("off")

hist2 = cv2.calcHist([image_binary], [0], None, [256], [0, 256])
plt.subplot(2,4,4)
plt.bar(range(256), hist2.flatten(), width=2)


# Try to use erosion, dilation, open, close to fill up the lines.

kernel = np.ones((5, 5), np.uint8)
dilated_img = cv2.dilate(image_binary, kernel, iterations=1)
plt.subplot(2,4,5)
plt.imshow(dilated_img,cmap="gray")
plt.title("dilated_img")
plt.axis("off")

eroded_img = cv2.erode(dilated_img, kernel, iterations=1)
plt.subplot(2,4,7)
plt.imshow(eroded_img,cmap="gray")
plt.title("eroded_img")
plt.axis("off")

# save result
cv2.imwrite('output/morpho_yellow.jpg', eroded_img)
# Out:
# _ =  110.0
# True

# %%
hsv_blue = cv2.imread('output/cropHSV_blue.jpg', cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(20,6.5))
plt.subplot(2,4,1)
plt.imshow(hsv_blue,cmap='gray')
plt.title("origin")
plt.axis("off")

hist1 = cv2.calcHist([hsv_blue], [0], None, [256], [0, 256])
plt.subplot(2,4,2)
plt.bar(range(256), hist1.flatten(), width=2)


_, image_binary = cv2.threshold(hsv_blue, 105, 255, cv2.THRESH_BINARY) ## (threshold, image)
plt.subplot(2,4,3)
plt.imshow(image_binary,cmap="gray")
plt.title("threshold")
plt.axis("off")

hist2 = cv2.calcHist([image_binary], [0], None, [256], [0, 256])
plt.subplot(2,4,4)
plt.bar(range(256), hist2.flatten(), width=2)

# Try to use erosion, dilation, open, close to fill up the lines.
kernel = np.ones((2, 2), np.uint8)
dilated_img = cv2.dilate(image_binary, kernel, iterations=6)
plt.subplot(2,4,5)
plt.imshow(dilated_img,cmap="gray")
plt.title("dilated_img")
plt.axis("off")

eroded_img = cv2.erode(dilated_img, kernel, iterations=7)
plt.subplot(2,4,6)
plt.imshow(eroded_img,cmap="gray")
plt.title("eroded_img")
plt.axis("off")

dilated_img = cv2.dilate(eroded_img, kernel, iterations=1)
plt.subplot(2,4,7)
plt.imshow(dilated_img,cmap="gray")
plt.title("dilated_img")
plt.axis("off")


# save result
cv2.imwrite('output/morpho_blue.jpg', dilated_img)
# Out:
# True

# %% [markdown]
# ## **6. Find countours**
#
# Use package to find the contours in the image.
#
# Practice:
# 1. Find the pad and probemark contours in the pad series images.
# 2. Calculate the countours area.

# %%
pad_task1 = cv2.imread('input/binary_task1.bmp')
ori_gray = cv2.cvtColor(pad_task1, cv2.COLOR_BGR2GRAY)
plt.subplot(121)
plt.imshow(ori_gray,cmap="gray")
plt.title("origin")
plt.axis("off")

# Find the pad and probemark contours and draw.

_, image_binary = cv2.threshold(ori_gray, 110, 255, cv2.THRESH_BINARY) ## (threshold, image)
contours, hierarchy = cv2.findContours(image_binary, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)  #cv2.RETR_EXTERNAL #cv2.RETR_TREE
# print(hierarchy)
# print(contours)

cv2.drawContours(pad_task1, contours, -1, (255,0,0),1)
plt.subplot(122)
plt.imshow(pad_task1)
plt.title("contours")
plt.axis("off")


pad_area = []
for i in range(len(contours)):
    area = cv2.contourArea(contours[i])
    pad_area.append(area)

# save and print result
cv2.imwrite('output/pad_task1_cont.bmp', pad_task1)
print('The pad area is ', pad_area)
# print('The probe mark area is ', probemark_area)
# Out:
# The pad area is  [2854.5, 6486.0, 108.0, 69.0, 1.5, 2779.0]
